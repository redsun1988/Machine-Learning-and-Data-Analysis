# %%
import numpy as np
import math as mt
from matplotlib import pylab as plt

def f(x):
    return mt.sin(x / 5) * mt.exp(x / 10) + 5 * mt.exp(-x / 2)
x = np.array([[1., 1.], [15., 1.]])
y = np.array([f(x[0, 0]), f(x[1, 0])])
a = np.linalg.solve(x, y)
plt.plot(x, y)
plt.show()

x = np.array([[1., 1., 1.], [15., 225., 1.], [8., 64., 1.]])
y = np.array([f(x[0, 0]), f(x[1, 0]), f(x[2, 0])])
a = np.linalg.solve(x, y)
plt.plot(x, y)
plt.show()

x = np.array([[1., 1., 1., 1.], [15., 225., 3375., 1.], [4., 16., 64., 1.], [10., 100., 1000., 1.]])
y = np.array([f(x[0, 0]), f(x[1, 0]), f(x[2, 0]), f(x[3, 0])])
a = np.linalg.solve(x, y)
print a
plt.plot(x, y)
plt.show()


file_obj = open('result2.txt', 'w')
string = str(a[3]) + ' ' + str(a[0]) + ' ' + str(a[1])+ ' ' + str(a[2])
file_obj.write(string)
file_obj.close()
# Out:
# [-1.29552587  0.19333685 -0.00823565  4.36264154]
