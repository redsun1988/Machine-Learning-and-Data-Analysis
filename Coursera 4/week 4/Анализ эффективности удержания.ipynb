# %%
import numpy as np
import pandas as pd
import scipy
from statsmodels.stats.weightstats import *

# %%
raw = pd.read_csv("churn_analysis.csv", sep=",", index_col=0)
raw.head(5)
# Out:
#   state  account_length  area_code intl_plan vmail_plan  vmail_message  \
# 0    KS             128        415        no        yes             25
# 1    OH             107        415        no        yes             26
# 2    NJ             137        415        no         no              0
# 3    OH              84        408       yes         no              0
# 4    OK              75        415       yes         no              0
#
#    day_mins  day_calls  day_charge  eve_mins   ...    night_mins  night_calls  \
# 0     265.1        110       45.07     197.4   ...         244.7           91
# 1     161.6        123       27.47     195.5   ...         254.4          103
# 2     243.4        114       41.38     121.2   ...         162.6          104
# 3     299.4         71       50.90      61.9   ...         196.9           89
# 4     166.7        113       28.34     148.3   ...         186.9          121
#
# ...

# %%
raw.state.values
# Out:
# array(['KS', 'OH', 'NJ', ..., 'RI', 'CT', 'TN'], dtype=object)

# %%
uniqueValues = np.unique(raw.state)[:2]
TreatmentFiltered = raw[raw["treatment"] == 1]
for value1 in uniqueValues:
    for value2 in uniqueValues:
        if value1 != value2:
            pairDataSet = TreatmentFiltered[TreatmentFiltered.state == value1]
            subtable = pd.pivot_table(pairDataSet,
                                      values="churn",
                                      index=["state"],
                                      columns=["area_code"],
                                      fill_value = 0)
            #print scipy.stats.chi2_contingency(subtable, correction=False).p
#pd.pivot_table(sales, values='sales', index=['date', 'store_id'],
#                     columns=['product_name'], fill_value = 0)
#scipy.stats.chi2_contingency(subtable, correction=False)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-77-2fe6fb116296> in <module>()
#       9                                       index=["state"],
#      10                                       columns=["area_code"],
# ---> 11                                       fill_value = 0)
#      12             #print scipy.stats.chi2_contingency(subtable, correction=False).p
#      13 #pd.pivot_table(sales, values='sales', index=['date', 'store_id'],
#
# C:\Users\KONYAYEV.MAKSIM\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\reshape\pivot.pyc in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     134
#     135     grouped = data.groupby(keys)
# --> 136     agged = grouped.agg(aggfunc)
#     137
#     138     table = agged
#
# ...
